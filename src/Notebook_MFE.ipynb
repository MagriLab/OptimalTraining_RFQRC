# %% [markdown]
# # Solving Dynamical Systems using Reservoir Computing

# %%
from QRC.solvers import *
from QRC.systems import *
from QRC.post_process import *
from QRC.crc import *
from QRC.qrc import *
from QRC.validation import *
#numpy
import numpy as np
#plotting libraries
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib as mpl
#scipy libraries
import sklearn
from skopt.space import Real
from skopt.learning import GaussianProcessRegressor as GPR
from skopt.learning.gaussian_process.kernels import Matern, WhiteKernel, Product, ConstantKernel
#time libraries
import h5py
import time
from datetime import date
from timeit import default_timer as timer
today = date.today()

mpl.rc('text', usetex = True)
mpl.rc('font', family = 'serif')
mpl.rcParams['text.usetex']

# TODO
# Add config file so that to run on HPC
# Out:
# True

# %% [markdown]
# # Select Systems and Parameters

# %%
#for Lorenz 63:
# if __name__ == "__main__":
#     dt = 0.01
#     tot_steps = 100000
#     upsample = 1
#     q0 =  np.array([7.432487609628195, 10.02071718705213, 29.62297428638419])
#     #q0 =  np.array([0, 1, 1])
#     N_transient = 2000


# save_fold = 'VPT_L63'
# system = Systems(dt,tot_steps,q0,upsample,N_transient)

# dim,N_lyap,N_t = system.set_param_lorenz63() # FOR MFE, N_t should be input so in set_param_MFE -- make it as input
# q = system.gen_data_lorenz63()


#for MFE:
if __name__ == "__main__":
    dt = 0.25
    tot_steps = 20000
    upsample = 1
    q0   = np.array([1, 0.07066, -0.07066, 0, 0, 0, 0, 0, 0]) 
    N_t = 2000
    N_transient = 1000

save_fold= 'MFE'
system = Systems(dt,tot_steps,q0,upsample,N_transient)
sys = 'MFE'
dim,N_lyap = system.set_param_MFE(N_t) 

run = False
save= False
load = True

if run:
    q = system.gen_data_MFE()

if save:
    fln = './data/MFE'+'MFE'+'_dt='+str(dt)+'_Nt='+str(N_t)+'_dim='+str(dim)+'_date='+str() # Enter Date
    hf = h5py.File(fln,'w')
    hf.create_dataset('q',data=q)
    hf.close()

if load:
    hf      = h5py.File('./data/MFE/'+'MFE'+'_dt='+str(dt)+'_Nt='+str(N_t)+'_dim='+str(dim)+'_date='+str('2023-07-31'))
    q       = np.array(hf.get('q'))
    hf.close()

# %% [markdown]
# # Pre-process input data

# %%
data_inputs = True
noise       = False # to add noise in flattened time series 
scaling     = False # to scale flattened time series 

if data_inputs:
    N_ts        = 20 # 1 for L63 and L96, 20 for MFE
    N_test_stat = 500 # Time series for testing after N_ts

    N_washout  = 2*N_lyap #10 before for L96 10 D , 2 before for L63 / MFE  
    N_val      = 2*N_lyap # 3 for L63 , # 5 for L96 , 2*N_lyap for MFE
    N_train    = 20*N_lyap #200 before for L96 10D , 20 before for L63 / MFE  
    N_test     = 500*N_lyap
 

# All above in this block are Inputs
q_unscaled = q
UU = q # backup of complete time series
print('Laminarized precentage', np.round(100-((q.shape[0])*100/N_t),2),'(relevant for MFE)')

q = q[:N_ts+N_test_stat,:,:] # trimmed time series

print('Retaining ',N_ts, 'series for training and validation')
print('Additional ',N_test_stat, 'series for testing and statistical predictions')

# Rescaling Input Time Series after flattening it (only retained series)
q0 = q.shape[0] # Total time series, Train+Val+Test
q1 = q.shape[1] # Length of each time series
q_U = q.reshape(q0*q1, dim)

if scaling:
    q = sklearn.preprocessing.minmax_scale(q_U, feature_range=(0, 1), axis=0, copy=True) # rescaling flattened array
    q  = q.reshape(q0,q1,dim) # making 3 dimensional again

# from here q has scaled data
q_tv = q[:N_ts,:,:]  # From q retaining training set (N_ts)
q_test = q[N_ts:N_ts+N_test_stat,:,:]  #From q removing retaining test set(N_test_stat)

# Training, Validation Parameters
UU = q_tv # Training, validation set
N0 = UU.shape[0] # Retained Time series for training
N1 = UU.shape[1] # Length of each time series
print('UU Size =',UU.shape) # 3 dim
U = UU.reshape(N0*N1, dim) # Generating flattened time series for addition of noise and normalization
print('U Size =',U.shape) # 2 dim 

if noise: # adding noise in training set
    target_snr_db=40
    seed=0
    UU = add_noise(U,target_snr_db,seed,dim,N0,N1)

#compute norm
U_data = U[:N_washout+N_train+N_val]
m = U_data.min(axis=0)
M = U_data.max(axis=0)
norm = M-m
u_mean = U_data.mean(axis=0)

# washout
U_washout = UU[:,:N_washout]
# training + validation
U_tv  = UU[:,N_washout:N_washout+N_train+N_val-1]
Y_tv  = UU[:,N_washout+1:N_washout+N_train+N_val]
# Testing
U_test  = UU[:,N_washout+N_train+N_val:N_washout+N_train+N_val+N_test-1]
Y_test  = UU[:,N_washout+N_train+N_val+1:N_washout+N_train+N_val+N_test]

print('N_lyap:', N_lyap)
print('N_train =',int(N_train/N_lyap),'N_lyap',' x ',str(N_ts),'series')
print('N =',int((N_washout+N_val+N_train)/N_lyap),'N_lyap',', Total steps of training=',int(N_washout+N_val+N_train),', Out of = ',N0*N1)
print('The shape of q_tv is '+str(q_tv.shape)+ ' to train on ' +str(N_ts)+  ' time series')
print('The shape of q_test is '+str(q_test.shape)+ ' to test ' +str(N_test_stat)+  ' time series, and for stats predictions (relevant for MFE)')
print('The shape of q is '+str(q.shape)+ ' combining above')
print('The shape of U_test is '+str(U_test.shape)+ ' combining above')
# Out:
# Laminarized precentage 27.95 (relevant for MFE)
# Retaining  20 series for training and validation
# Additional  500 series for testing and statistical predictions
# UU Size = (20, 16000, 9)
# U Size = (320000, 9)
# N_lyap: 245
# N_train = 20 N_lyap  x  20 series
# N = 24 N_lyap , Total steps of training= 5880 , Out of =  320000
# The shape of q_tv is (20, 16000, 9) to train on 20 time series
# The shape of q_test is (500, 16000, 9) to test 500 time series, and for stats predictions (relevant for MFE)
# The shape of q is (520, 16000, 9) combining above
# The shape of U_test is (20, 10120, 9) combining above

# %% [markdown]
# # Visualize input data

# %%
# l1 = 8000
# l2 = 5000
# l3 = 5000

# plot_lorenz63_attractor(U,l1)
# plot_lorenz63_time(U,N_lyap,l2,l3)
# plt.show()

# %% [markdown]
# # Classical Reservoir Initialization

# %%
# Required Input Parameters
bias_in   = np.array([np.mean(np.abs((U_data-u_mean)/norm))]) #input bias (average absolute value of the inputs)
bias_out  = np.array([1.]) #output bias 
N_units   = 256 #neurons
density = 0.11 # L63
#density = 0.01 # L96
#connectivity = 30

# Predefining Hyperparameter to initiate a class
tikh = np.array([1e-9])  # Tikhonov factor 
sigma_in = 1 # input scaling
rho = 1
epsilon = 1

# Random Weight Matrices Seed
seed = 2

sparseness = 1 - density
connectivity = (1 -  sparseness)*(N_units-1)

# sparseness = 1-((connectivity)/(N_units-1))
# density    = 1-sparseness
print('Density(D) = ',np.round(density,2))
print('Connectivity = ', np.round(connectivity,2))

esn = EchoStateNetwork(tikh,sigma_in,rho,epsilon,bias_in,bias_out,N_units,dim,density)
esn.norm_u = norm
# Out:
# Density(D) =  0.11
# Connectivity =  28.05

# %% [markdown]
# # Validation (hyperparameter tuning)

# %%
n_in        = 10               #Number of Initial random points
n_tot       = 50               #Total number of function evaluations

#range for hyperparameters 
spec_in     = np.log10(0.01)   
spec_end    = np.log10(1.0)   
epsilon_in  = 0.01
epsilon_end = 1
scaling_in  = 0.01
scaling_end = 1
#Number of Networks in the ensemble
ensemble = 5      
    
search_space = [Real(spec_in, spec_end, name='spectral_radius'),
            Real(epsilon_in, epsilon_end, name='epsilon'),
            Real(scaling_in,scaling_end, name = 'input_scaling')]

kernell = ConstantKernel(constant_value=1.0, constant_value_bounds=(1e-1, 3e0)) *\
            Matern(length_scale=[0.2,0.1,0.3], nu=2.5, length_scale_bounds=(5e-2, 1e1)) 


k= 0
# Which validaton strategy (implemented in Val_Functions.ipynb)
val      = RVC_Noise_upt
N_fo     = max(50,2)            # number of validation intervals
N_in     = N_washout                  # timesteps before the first validation interval (can't be 0 due to implementation)
N_fw     = (N_train-N_val)//(N_fo-1) # how many steps forward the validation interval is shifted (in this way they are evenly spaced)

#Quantities to be saved
par      = np.zeros((ensemble, 5))      # GP parameters
x_iters  = np.zeros((ensemble,n_tot,len(search_space))) # coordinates in hp space where f has been evaluated
f_iters  = np.zeros((ensemble,n_tot))   # values of f at those coordinates
minimum  = np.zeros((ensemble, len(search_space)+2))      # minima found per each member of the ensemble

# to store optimal hyperparameters and matrices
tikh_opt = np.zeros(n_tot)
Woutt    = np.zeros(((ensemble, N_units+1,dim)))
Winn     = [] #save as list to keep single elements sparse
Ws       = [] 
biass    = []
rho_ens  = []
epsilon_ens = []
sigma_in_ens = []
Xa_cc        = []
LHS_cc       = []
RHS_cc       = []

# save the final gp reconstruction for each network
gps        = [None]*ensemble

# to print performance of every set of hyperparameters
# print_flag = False

# %%
## TODO fix k, global issues for classical hyperparam opt
run_hyperparam = True
save = True

if run_hyperparam:
    for i in range(ensemble):
        
        print('Realization    :',i+1)
        
        k   = 0
        
        # Win and W generation
        seed= i+1
        rnd = np.random.RandomState(seed)

        Win =  esn.gen_input_matrix(seed)
        W =  esn.gen_reservoir_matrix(seed)
        
        # Bayesian Optimization
        tt       = time.time()
        res      = validate(val,kernell,search_space,n_in,n_tot,esn,tikh,N_fo,N_fw,N_in,N_val,N_washout,U,U_washout,U_tv,Y_tv,Win,W,k,tikh_opt)
        print('Total time for the network:', time.time() - tt)
        
        #Saving Quantities for post_processing
        gps[i]     = res.models[-1]    
        gp         = gps[i]
        x_iters[i] = np.array(res.x_iters)
        f_iters[i] = np.array(res.func_vals)
        minimum[i] = np.append(res.x,[tikh_opt[np.argmin(f_iters[i])],res.fun])
        params     = gp.kernel_.get_params()
        key        = sorted(params)
        par[i]     = np.array([params[key[2]],params[key[5]][0], 1, gp.noise_,params[key[5]][1]])

        esn.rho      = 10**minimum[i,0]
        esn.epsilon  = minimum[i,1]
        esn.sigma_in = minimum[i,2]

        Woutt[i] = esn.train(U_washout, U_tv, Y_tv,Win,W)[1]

        Winn    += [Win] 
        Ws      += [W]   

        #Plotting Optimization Convergence for each network
        print('Best Results: x', 10**minimum[i,0], minimum[i,1],minimum[i,2] ,minimum[i,3],', Min Obj Function =', minimum[i,4])
        print('Hyperparamters:',esn.rho,esn.epsilon,esn.sigma_in)

        plt.rcParams["figure.figsize"] = (15,2)
        
        
        if save:    
            fln = './data/MFE/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble) 
            hf = h5py.File(fln,'w')
            hf.create_dataset('minimum',data=minimum)
            hf.close()
# Out:
# Realization    : 1
# closed-loop time: 2.125826835632324
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 3.470867364683542
# closed-loop time: 2.1446263790130615
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 2.4759257071837895
# closed-loop time: 2.1450016498565674
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 3.23127078726203
# closed-loop time: 2.121082305908203
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 0.8211355018508283
# closed-loop time: 2.153764247894287
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 1.2412046749142116
# closed-loop time: 2.1519622802734375
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 0.9539810572832921
# closed-loop time: 2.132688522338867
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 4.15839731882494
# closed-loop time: 2.122779607772827
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 2.2857438454418126
# closed-loop time: 2.114690065383911
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 3.0292738812108353
# closed-loop time: 2.09316086769104
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 3.4334077385311645
# closed-loop time: 2.1119792461395264
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.9948973524232558 1e-09 0.7751891493870271 1.521963506360726
# closed-loop time: 2.106065273284912
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.33 1.0 1e-09 1.0 -0.3750389584363103
# closed-loop time: 2.084359645843506
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -0.5384978142287926
# closed-loop time: 2.1019937992095947
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.86 0.870260351923993 1e-09 1.0 -1.050572605540479
# closed-loop time: 2.237710952758789
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.75231889375515 1e-09 1.0 -0.8479678729595577
# closed-loop time: 2.140875816345215
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8479340016761929 1e-09 0.829114804116477 -0.8559374204354369
# closed-loop time: 2.1866655349731445
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.39 0.8267561613374391 1e-09 1.0 0.12958162507193882
# closed-loop time: 2.1258585453033447
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.8177938988405256 -0.7109727162807638
# closed-loop time: 2.2125332355499268
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5479918389531984 1e-09 1.0 -0.7435531845292789
# closed-loop time: 2.2371952533721924
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.01 1e-09 0.9085704248506438 3.078478494405325
# closed-loop time: 2.108764410018921
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.3761812582960392 -0.9986916055113956
# closed-loop time: 2.9028093814849854
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.01 0.6042945891695505
# closed-loop time: 2.7136764526367188
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.5750959192935365 -0.8223841211341232
# closed-loop time: 2.1276965141296387
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8629423513359085 1e-09 0.573625257319572 -0.7864604297170382
# closed-loop time: 2.963400363922119
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6950213507096701 1e-09 0.8177300169901971 -0.7312615031160132
# closed-loop time: 2.134737730026245
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.391762685461911
# closed-loop time: 2.1365833282470703
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.717920552468834 -2.354597426247317
# closed-loop time: 2.7818284034729004
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.04854387737480022 -2.2992711594419837
# closed-loop time: 2.153642177581787
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.4404681950655342 -2.2775037156549582
# /home/oa1422/OpenAccess/env_opt/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# closed-loop time: 2.130878210067749
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.391762685461911
# closed-loop time: 2.1439273357391357
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.9336394509015021 -2.327698156051873
# closed-loop time: 2.688986301422119
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.01 -2.2438195338443516
# closed-loop time: 2.1620070934295654
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.31821702438448984 -2.218778481046952
# closed-loop time: 2.366109609603882
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.8669605029833238 -2.3773182313213805
# closed-loop time: 2.565099000930786
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.09864790999583475 1e-09 0.01 -2.0517126387493545
# closed-loop time: 2.180245876312256
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.08174415940024345 1e-09 1.0 0.2335131988427568
# closed-loop time: 2.1072075366973877
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.04799434006622426 1e-09 0.01 -2.2256892758382145
# closed-loop time: 2.2537872791290283
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.6384088636355162 -2.2672156851962226
# closed-loop time: 2.7143571376800537
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.09353790709532611 1e-09 0.01 -2.183477853983076
# closed-loop time: 2.11969256401062
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.039770972483519164 1e-09 0.01 -2.2998280505784314
# closed-loop time: 2.108950614929199
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.051037393874960854 1e-09 0.01 -2.183540124903711
# closed-loop time: 2.7174911499023438
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.08 0.01 1e-09 0.01 -2.295731144586817
# closed-loop time: 2.091073751449585
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.1 0.06856853913567569 1e-09 0.01 -1.9644256546502243
# closed-loop time: 2.0757646560668945
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6720494412475609 1e-09 0.01 1.2686277060819744
# closed-loop time: 2.0987954139709473
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.01 1e-09 0.15380122057493062 -2.3734904276282496
# closed-loop time: 2.072540521621704
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.01 1e-09 0.36084931123306596 -2.263198295760163
# closed-loop time: 2.0866758823394775
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.21343988131128125 1e-09 0.01 2.2096434374786416
# closed-loop time: 2.099825382232666
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.01 1e-09 0.01 -2.1891198120706323
# closed-loop time: 2.1156139373779297
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.07 0.02941252463267533 1e-09 0.14658258452042877 -2.0566110776242934
# closed-loop time: 2.0829992294311523
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.3960464442127125 1e-09 1.0 -0.40265413167574027
# Total time for the network: 481.96279287338257
# Best Results: x 0.01 1.0 0.01 0.0 , Min Obj Function = -2.391762685461911
# Hyperparamters: 0.01 1.0 0.01
# Realization    : 2
# closed-loop time: 2.078890323638916
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 3.619906674648303
# closed-loop time: 2.076249599456787
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 1.96248626323373
# closed-loop time: 2.097032308578491
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 3.053368049246044
# closed-loop time: 2.0715396404266357
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 1.6610171823403115
# closed-loop time: 2.0869557857513428
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 2.500913605200611
# closed-loop time: 2.0589022636413574
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 0.9324184447124508
# closed-loop time: 2.0769717693328857
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 4.54660089653844
# closed-loop time: 2.085151433944702
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 2.116124332093971
# closed-loop time: 2.077920436859131
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 3.0512273582218854
# closed-loop time: 2.0967049598693848
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 3.6401700108640647
# closed-loop time: 2.115899085998535
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 1.0 1.8899200194292423
# closed-loop time: 2.103653907775879
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7232196856397198 1e-09 1.0 1.0598946189971932
# closed-loop time: 2.102628707885742
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.6311225902106172 1e-09 0.8746258439135607 0.9044030993207707
# closed-loop time: 2.0949933528900146
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8994332943395027 1e-09 1.0 -0.4497537032030812
# closed-loop time: 2.0930614471435547
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.8430107700421341 -0.3186152965446032
# closed-loop time: 2.107426166534424
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -0.3954499323897596
# closed-loop time: 2.1331329345703125
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.53 0.9288492515883557 1e-09 1.0 -0.3422607368604648
# closed-loop time: 2.087458610534668
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6401793114607237 1e-09 1.0 -0.7404548673391875
# closed-loop time: 2.1171417236328125
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.43306142877362874 1e-09 1.0 -0.47899815249248306
# closed-loop time: 2.065054178237915
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6335763977178627 1e-09 0.8847035260544068 -0.7009073925314196
# closed-loop time: 2.112133741378784
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.72 0.6288054676573992 1e-09 1.0 -0.3673877233695712
# closed-loop time: 2.091205596923828
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6534164932300766 1e-09 0.964625456130765 -0.7442846414640628
# closed-loop time: 2.1092073917388916
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.19 1.0 1e-09 1.0 0.009813620335879725
# closed-loop time: 2.069727659225464
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.24668943546018968 -0.7578648951973771
# closed-loop time: 2.0982260704040527
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.38870493305288184 -0.7658906727792248
# closed-loop time: 2.1036698818206787
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.62 1.0 1e-09 0.36183970219655737 -0.3272170801574938
# closed-loop time: 2.073563814163208
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8790789739096546 1e-09 0.37464662647686764 -0.8198406727233367
# closed-loop time: 2.1139307022094727
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8187227945913003 1e-09 0.5196853773073528 -0.7106907964928213
# closed-loop time: 2.599092483520508
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9271240245131529 1e-09 0.3421426966824822 -0.8135935349469822
# closed-loop time: 2.0804250240325928
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.01 1.4091760296237021
# closed-loop time: 2.0893654823303223
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6589990269370065 1e-09 0.4447954735283201 -0.6760931309128737
# closed-loop time: 2.2968382835388184
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6122718305366097 1e-09 0.6481810254269031 -0.6600658007590602
# closed-loop time: 2.28108811378479
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.819600239412181 1e-09 0.34004607569874723 -0.7876906446443047
# closed-loop time: 2.0894012451171875
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.31 1.0 1e-09 0.7536512710278045 -0.0920973193662245
# closed-loop time: 2.110450267791748
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.30818759689215264 -0.8209918544324871
# closed-loop time: 2.11989426612854
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.3881993987944354
# closed-loop time: 2.072962522506714
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.883105183457992 -2.37831381890376
# closed-loop time: 2.109313488006592
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.5686435997302873 -2.3236714296059717
# closed-loop time: 2.064517021179199
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.02558229873686757 -2.342911216444748
# closed-loop time: 2.0838112831115723
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.24445693687940045 -2.2188964083657727
# closed-loop time: 2.2602038383483887
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.7253353687856631 -2.3582180493721636
# closed-loop time: 2.1381239891052246
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.01 -2.248156380533665
# closed-loop time: 2.1483452320098877
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.0876627137910662 -2.2430081366174397
# closed-loop time: 2.1456282138824463
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.40496718312231517 -2.2686043683061734
# closed-loop time: 2.1564149856567383
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.6420397320057913 -2.3422351120533715
# closed-loop time: 2.1411309242248535
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.3881993987944354
# closed-loop time: 2.1285810470581055
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.16764733888312594 -2.283128795353718
# closed-loop time: 2.3062100410461426
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.9394717884872587 -2.383473558709933
# closed-loop time: 2.103020191192627
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.01 1e-09 0.01 -2.180809684297956
# closed-loop time: 2.087353467941284
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.8101948818410896 -2.3702773775649852
# Total time for the network: 454.4018247127533
# Best Results: x 0.01 1.0 0.01 0.0 , Min Obj Function = -2.3881993987944354
# Hyperparamters: 0.01 1.0 0.01
# Realization    : 3
# closed-loop time: 2.123537540435791
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 2.6646462172385617
# closed-loop time: 2.1016108989715576
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 1.4324259030163182
# closed-loop time: 2.1054916381835938
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 3.241439091456004
# closed-loop time: 2.1201391220092773
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 0.38930349791195895
# closed-loop time: 2.130181312561035
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 2.053557477024399
# closed-loop time: 2.1189913749694824
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 0.41058654059408994
# closed-loop time: 2.1026859283447266
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 4.85059751459711
# closed-loop time: 2.119896411895752
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 2.2869909743481305
# closed-loop time: 2.1363003253936768
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 3.1645565232371924
# closed-loop time: 2.099799394607544
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 3.6495051135856973
# closed-loop time: 2.120189905166626
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.9803273052780886 1e-09 0.8968460009360464 0.09232261193332288
# closed-loop time: 2.1200149059295654
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.7660531808247575 0.3274591652287755
# closed-loop time: 2.1310057640075684
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.1 1.0 1e-09 1.0 1.8400609916509507
# closed-loop time: 2.1391661167144775
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 1.0 0.08660492502039319
# closed-loop time: 2.1284091472625732
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.9045529174166298 1e-09 1.0 0.08714894199654659
# closed-loop time: 2.132873058319092
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.01 1e-09 1.0 3.254277247211801
# closed-loop time: 2.101555824279785
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.9289979829186558 1e-09 0.908972714527504 -0.4623497852216061
# closed-loop time: 2.124727249145508
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.404665941695916
# closed-loop time: 2.0997955799102783
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.7601004843528466 -2.3766701421209406
# closed-loop time: 2.0623011589050293
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.47932628046681786 -2.3003123895027446
# closed-loop time: 2.0990352630615234
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.7642838951777103 -2.377377309309925
# closed-loop time: 2.096954584121704
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.01 -2.270154743006992
# closed-loop time: 2.1077704429626465
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.03590066151813267 1e-09 0.586556113315808 -2.183157689979741
# closed-loop time: 2.0983633995056152
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.01 1e-09 0.01 -2.1763299689926394
# closed-loop time: 2.0982155799865723
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.26031553505226873 -2.224415474694139
# closed-loop time: 2.176577568054199
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7057748930844072 1e-09 1.0 -0.8217913099015489
# closed-loop time: 2.1026015281677246
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.5943774657529591 1e-09 1.0 1.126505910622389
# closed-loop time: 2.1010944843292236
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8110231452440481 1e-09 1.0 -0.9127702158299545
# closed-loop time: 2.378969430923462
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.060986460502574044 1e-09 0.01 -2.162413349465931
# closed-loop time: 3.0752642154693604
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.9667912188642476 -2.3454548846885626
# closed-loop time: 2.2851178646087646
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.10746229385149285 1e-09 0.01 -2.168727163102089
# closed-loop time: 2.0935423374176025
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.09056949953709274 1e-09 1.0 -1.4740790829107195
# closed-loop time: 2.0890450477600098
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.06633647577956885 1e-09 0.01 -2.1990778753897366
# closed-loop time: 2.4226651191711426
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.534226484844166 -2.2510167569445994
# closed-loop time: 2.5375633239746094
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.9048032334160256 -2.3961903970659537
# closed-loop time: 2.074442148208618
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5853630832700014 1e-09 1.0 -0.8293851200310673
# closed-loop time: 2.08451247215271
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.1962560334163606 -0.8378077794425083
# closed-loop time: 3.036137342453003
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.18071522669902132 -2.2744395946115326
# closed-loop time: 2.0976309776306152
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9024473871089301 1e-09 0.01 0.786148188887545
# closed-loop time: 2.0867269039154053
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6799959929890095 -0.8784105730951387
# closed-loop time: 2.2536826133728027
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.14 0.7623122556096685 1e-09 1.0 1.567212486243336
# closed-loop time: 3.048065423965454
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.6891673255736325 -2.3630264410264776
# closed-loop time: 2.102898120880127
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6444982767224208 1e-09 0.01 0.5204026623735697
# closed-loop time: 2.062093496322632
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.02978340178258604 1e-09 0.01 -2.1450276289261394
# closed-loop time: 2.4890618324279785
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.03787975112631774 1e-09 1.0 -2.1075510475351344
# closed-loop time: 2.0870797634124756
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.10498965795489162 1e-09 0.01 -1.1613297082040848
# closed-loop time: 2.080883026123047
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.18022614831672112 1e-09 0.01 -0.7761350273451955
# closed-loop time: 2.319345712661743
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.3391999225315346 1e-09 1.0 1.7005409611719935
# closed-loop time: 2.5961616039276123
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.18 0.608395674935405 1e-09 1.0 1.3758223349770757
# closed-loop time: 2.08303165435791
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.07991711792374875 1e-09 0.3226115334702412 -1.6155276379225842
# Total time for the network: 477.0454103946686
# Best Results: x 0.01 1.0 0.01 0.0 , Min Obj Function = -2.404665941695916
# Hyperparamters: 0.01 1.0 0.01
# Realization    : 4
# closed-loop time: 2.0965185165405273
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 3.2179250151265304
# closed-loop time: 2.093191385269165
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 2.4542561483456655
# closed-loop time: 2.097973585128784
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 2.951441540887543
# closed-loop time: 2.1279611587524414
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 3.0852348889014705
# closed-loop time: 2.0781874656677246
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 1.801302929361981
# closed-loop time: 2.1024363040924072
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 1.6602189596251042
# closed-loop time: 2.097168207168579
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 4.947809524092351
# closed-loop time: 2.0920634269714355
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 1.9245447897894619
# closed-loop time: 2.087437629699707
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 2.774317012893257
# closed-loop time: 2.0843868255615234
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 1.720545361500191
# closed-loop time: 2.1012628078460693
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.53 0.7485379231044298 1e-09 0.7868472378892691 -0.5888668548486131
# closed-loop time: 2.0942301750183105
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.83 0.7674872388214996 1e-09 0.7465072591732517 -0.5698038666856813
# closed-loop time: 2.322711706161499
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.83 0.7236994053188321 1e-09 0.01 1.8458124294888412
# closed-loop time: 2.1207773685455322
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.69 0.9542703251179214 1e-09 1.0 -0.5330024408019465
# closed-loop time: 2.1201529502868652
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.68 0.7005486136896126 1e-09 1.0 -0.41828522935928286
# closed-loop time: 2.11255145072937
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.66 0.9127026825368312 1e-09 0.7915554414051482 -0.5356167869149797
# closed-loop time: 2.1098334789276123
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.38 0.9070053961118919 1e-09 1.0 -1.8005442592639846
# closed-loop time: 2.5777368545532227
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.28 1.0 1e-09 1.0 -0.7779702363625942
# closed-loop time: 2.120666027069092
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.31 0.6827825036708229 1e-09 1.0 -0.11931515666673975
# closed-loop time: 2.1069273948669434
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.3921188393404167
# closed-loop time: 2.1126019954681396
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.4225017673234966 -2.268019164540505
# /home/oa1422/OpenAccess/env_opt/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# closed-loop time: 2.0878729820251465
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.3921188393404167
# closed-loop time: 2.6178596019744873
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.11498852763527911 1e-09 0.8678969000547586 0.29721732256017414
# closed-loop time: 2.1023757457733154
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.8348316615126599 -2.309177090310483
# closed-loop time: 2.1137149333953857
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.7773624546262281 -2.3691679728500485
# closed-loop time: 2.0853371620178223
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.01 -2.2478687182648436
# closed-loop time: 2.1094350814819336
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.01 -2.2750542353497156
# closed-loop time: 2.0898489952087402
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.23 0.8466629059566207 1e-09 1.0 0.26035722164583314
# closed-loop time: 2.1137807369232178
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.15 0.9370287841949619 1e-09 1.0 0.04471911134094429
# closed-loop time: 2.097097396850586
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.01 1e-09 1.0 -2.252991367471012
# closed-loop time: 2.0938918590545654
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.01 1e-09 0.01 -2.193988436896428
# closed-loop time: 2.098992109298706
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.06 0.8892228722241213 1e-09 1.0 1.7903627262181234
# closed-loop time: 2.1220450401306152
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.07 0.979037154821891 1e-09 1.0 1.4523330746766743
# closed-loop time: 2.1099038124084473
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.01 1e-09 0.48385743399746073 -2.2361192091682445
# closed-loop time: 2.099440813064575
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.015189148460887383 1e-09 1.0 -2.3658979319197417
# closed-loop time: 2.0950183868408203
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.055104329569538736 1e-09 0.01 -2.2764705227027706
# closed-loop time: 2.103355646133423
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.04941157945573255 1e-09 1.0 0.05277605264697314
# closed-loop time: 2.093827724456787
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.06313800126504063 1e-09 0.01 -2.207798769105358
# closed-loop time: 2.0925540924072266
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.06706625834355466 1e-09 0.9918164693604037 1.7793078114352816
# closed-loop time: 2.10410213470459
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.04126872837163729 1e-09 0.01 -2.1843579245299236
# closed-loop time: 2.101769208908081
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.04268920107415792 1e-09 0.01 -2.2411178007445107
# closed-loop time: 2.107410430908203
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.10399223379773699 1e-09 0.01 -1.815369415082377
# closed-loop time: 2.0949058532714844
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.5921254901770716 1e-09 0.01 4.4389076428412295
# closed-loop time: 2.0809426307678223
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.20185273740627055 1e-09 0.01 1.7144382469992663
# closed-loop time: 2.113497257232666
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.01 1e-09 1.0 -2.295768598700632
# closed-loop time: 2.10012149810791
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5554526163294639 1e-09 1.0 -0.5529814540278712
# closed-loop time: 2.0918216705322266
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 1.0 1e-09 0.01 1.6438510873337946
# closed-loop time: 2.1139373779296875
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.038404520694092496 1e-09 0.47749620152444194 -1.8219009445322962
# closed-loop time: 2.0875191688537598
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.8441618998927715 -2.378025332768472
# closed-loop time: 2.9629266262054443
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.08898084007808804 1e-09 0.01 -2.1705201683723665
# Total time for the network: 459.2030384540558
# Best Results: x 0.01 1.0 0.01 0.0 , Min Obj Function = -2.3921188393404167
# Hyperparamters: 0.01 1.0 0.01
# Realization    : 5
# closed-loop time: 2.0995824337005615
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 3.1162693928778036
# closed-loop time: 2.085430145263672
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 1.9829689554490526
# closed-loop time: 2.093651533126831
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 2.611657527103262
# closed-loop time: 2.1197338104248047
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 2.5846600382161453
# closed-loop time: 2.1378536224365234
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 0.8302938187881197
# closed-loop time: 2.1028389930725098
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 0.649637821855294
# closed-loop time: 2.094926357269287
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 3.628586364527598
# closed-loop time: 2.092410087585449
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 2.171210621162456
# closed-loop time: 2.081400156021118
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 2.900536215311896
# closed-loop time: 2.07651686668396
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 2.2915412533552773
# closed-loop time: 2.072294235229492
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.51 0.19852264887101978 1e-09 0.8532575725233749 1.6208761229730158
# closed-loop time: 2.0979268550872803
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.9474879096680457 1e-09 0.8993711074406502 1.7339639495379329
# closed-loop time: 2.0963985919952393
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.06931019267053955 1e-09 0.879846110905704 -0.7202777135042981
# closed-loop time: 2.1323788166046143
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.051895590868926395 1e-09 1.0 -1.6790416266743724
# closed-loop time: 2.0785717964172363
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.3886948825892564
# closed-loop time: 2.098051071166992
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -0.7795707051737131
# closed-loop time: 2.0836634635925293
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.5072856659794722 -0.873347790617864
# closed-loop time: 2.0805506706237793
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.01 -2.269572679854069
# closed-loop time: 2.0948333740234375
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.019125550036889972 1e-09 1.0 -2.2573558077903018
# closed-loop time: 2.0790047645568848
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.022746088238976177 1e-09 1.0 -2.287413600094512
# closed-loop time: 2.0630927085876465
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.905988417721046 1e-09 0.01 0.5063732091250643
# closed-loop time: 2.1295759677886963
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.6281874689408192 1e-09 0.9626675249773443 0.6521077836923302
# closed-loop time: 2.100172281265259
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.3886948825892564
# closed-loop time: 2.081470012664795
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6645570619855347 1e-09 1.0 -0.7566657690156149
# closed-loop time: 2.0925819873809814
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5838754739229021 1e-09 0.20133969632991613 -0.1725021354997445
# closed-loop time: 2.3123579025268555
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7522019892363672 1e-09 0.09378154960160684 -0.19168515478582002
# closed-loop time: 2.0889880657196045
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.15 0.6661834533321481 1e-09 1.0 0.4263052964109916
# closed-loop time: 2.1041131019592285
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.17 1.0 1e-09 0.01 2.8297425050105107
# closed-loop time: 2.1007630825042725
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.01 1e-09 1.0 -2.2850984573608684
# closed-loop time: 2.121109962463379
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.01 1e-09 0.01 -2.1809201511698832
# closed-loop time: 2.0970640182495117
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.2746144968580306 1e-09 1.0 2.231582901136324
# closed-loop time: 2.0763039588928223
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.07 0.01 1e-09 1.0 -2.2340028128002674
# closed-loop time: 2.0639472007751465
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.032667690257870446 1e-09 1.0 -0.20787765644491252
# closed-loop time: 2.1130685806274414
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8237808289186543 1e-09 0.36458024661013516 -0.49656133474394515
# closed-loop time: 2.0877578258514404
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.08 0.5632602050582244 1e-09 0.09441507784834265 3.9219271846516732
# closed-loop time: 2.2305238246917725
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.17145545111829982 1e-09 0.5203701312508625 2.314340441447819
# closed-loop time: 2.679542303085327
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.22 0.7821521876722691 1e-09 1.0 -0.11663712347632536
# closed-loop time: 2.088139772415161
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.49502330546856566 1e-09 1.0 -0.4448713540229115
# closed-loop time: 2.2478814125061035
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 1.0 -2.3303170167869434
# closed-loop time: 2.8361289501190186
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.22 0.8559990287449768 1e-09 0.01 2.954176347572554
# closed-loop time: 2.093273401260376
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.23 0.7237074932309333 1e-09 1.0 -0.07929838674118847
# closed-loop time: 2.072242259979248
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.42615427192774413 1e-09 0.5281966887336147 -0.10003056154224989
# closed-loop time: 2.490995168685913
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -2.3886948825892564
# closed-loop time: 2.379790782928467
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.03 0.6899299562781601 1e-09 0.01 6.27869607688215
# closed-loop time: 2.0597710609436035
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.11 0.01 1e-09 1.0 -2.247190396590425
# closed-loop time: 2.073965311050415
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.01 1e-09 0.4952960393008928 -2.232031163680124
# closed-loop time: 3.1651575565338135
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.39 0.6362814219373891 1e-09 1.0 0.10191132280558554
# closed-loop time: 2.084167718887329
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.48764490329015453 1e-09 0.01 5.273608777265206
# closed-loop time: 2.0597989559173584
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.09 0.01 1e-09 0.01 -2.306140748235766
# closed-loop time: 3.182544469833374
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9603805375662787 1e-09 0.01 0.39683046401816297
# Total time for the network: 466.37249994277954
# Best Results: x 0.01 1.0 0.01 0.0 , Min Obj Function = -2.3886948825892564
# Hyperparamters: 0.01 1.0 0.01

# %% [markdown]
# # Loading Hyperparameters

# %%
# hf       = h5py.File('./data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-noise')
# hf       = h5py.File('./data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-noise'+str(noise))
# hf       = h5py.File('./data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble))
# minimum       = np.array(hf.get('minimum'))
# hf.close()

#hf       = h5py.File('./data/MFE/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-noise') # With Noise
hf       = h5py.File('./data/MFE/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)) 
minimum       = np.array(hf.get('minimum'))
hf.close()


for i in range(ensemble):
    print('Realization    :',i+1)

    esn.rho      = 10**minimum[i,0]
    esn.epsilon  = minimum[i,1]
    esn.sigma_in = minimum[i,2]
    seed= i+1
    rnd = np.random.RandomState(seed)
    
    
    Win =  esn.gen_input_matrix(seed)
    W =  esn.gen_reservoir_matrix(seed)
    
    Xa, Wout_p, LHS, RHS =  esn.train(U_washout, U_tv, Y_tv,Win,W)
    
    Woutt[i] = Wout_p
    
    Winn    += [Win] 
    Ws      += [W]
    Xa_cc   += [Xa]
    LHS_cc  += [LHS]
    RHS_cc  += [RHS]
# Out:
# Realization    : 1
# Realization    : 2
# Realization    : 3
# Realization    : 4
# Realization    : 5

# %% [markdown]
# # Quantum Reservoir Computing - Initialization

# %%
# Defining Qbit and Cbits
n              = 8 # 9 Qubits and classical
Nres           = 2**n # Total Reservoir Size
qubits         = n

# Required Input Parameters
N_units_q      = Nres #neurons or N_res in paper
bias_in        = np.array([np.mean(np.abs((U_data-u_mean)/norm))])  # Input bias, b_in to break the inherent symmetry of ESN Structure
bias_out       = np.array([1]) #output bias 

# Hyperparameters
tikh_q        = np.array([1e-12])  # Tikhonov Param (Beta),  adds a regularization or weight decay term that penalizes large Wout values 
sigma_in_q    = 1
rho_q         = 1.0 # [Spectral Radius]
epsilon_q     = 0.05 # Leaking Rate

# Ensembles for QRC
qu_ensemble   = 1

# %% [markdown]
# # Training

# %%
Configurations = ['Linear+Full+FullSymmetric','Linear+Linear+Linear','None+Linear+Linear','None+Full+FullSymmetric','None+Products+Linear']
config_list    = ['config1','config2','config3','config4','config5']
qc_type        = config_list[3]
config         = 4 # for initializing class its +1 of the list above

emulator_list  = ['sv_sim','qasm_sim']
emulator       = emulator_list[0]

method_list    = ['sv','shots1k','shots5k','shots10k','shots20k','shots30k','shots40k','shots50k','shots75k','shots100k','shots200k','shots1']
shot_list      = [None,1000,5000,10000,20000,30000,40000,50000,75000,100000,200000,400000,1]

## SHOT INPUT
shot_index     = 0

method = method_list[shot_index]
total_shots  = shot_list[shot_index]


shots = total_shots

snapshots = 1
print('Configuration:',qc_type,'Emulator:',emulator,'Total shots:',total_shots,'Individual Shots:',shots)

# Initialize Class
QESN   = QuantumReservoirNetwork(rho_q,epsilon_q,sigma_in_q,tikh_q,bias_in,bias_out,qubits,N_units_q,dim,config,emulator,shots,snapshots)

# Parameterized or not
QESN.method_qc(parameterized=False)

# Generate parameterized quantum circuit for a given configuration
# QESN.gen_param_quantumcircuit()

quantum_training = True
run_training     = True
save_training    = True
load_training    = False

Xa_qq    = []
Woutt_qq    = np.zeros(((qu_ensemble, QESN.N_units+1,dim)))
LHS_qq   = []
RHS_qq   = []
alpha_qc = []

eps_fix  = 0.05
tikh_q   = np.array([1e-12])
eps_q_list = np.linspace(0.05,0.3,qu_ensemble)
eps_q_list = np.ones(len(eps_q_list))*eps_fix
alpha_range    = 4*np.pi

start = timer()

if quantum_training:
    for i in range(qu_ensemble):
        
        print('Network',i+1,' out of ',qu_ensemble)
        seed           = i
        
        # Quantum Variational Part
        QESN.epsilon_q = eps_q_list[i]

        alpha_q          = QESN.gen_random_unitary(i,alpha_range)
        alpha_qc        += [alpha_q]


        if load_training:
            print('Loading existing Wout matrix')
            #hf       = h5py.File('./data/MFE/Woutt_qq='+str(dt)+'-Nres'+str(N_units_q)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'script')#+'-noise')
            #hf        = h5py.File('./data/MFE/Woutt_qq='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            hf       = h5py.File('./data/MFE/Woutt_qq='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            #hf      = h5py.File('./data/{}_New/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            #hf      = h5py.File('./data/{}/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            
            Woutt_qq       = np.array(hf.get('Woutt_qq'))
            hf.close()
        

        if run_training:
            print('Training...')
            Xa_qc, Woutt_qc, LHS_qc, RHS_qc = QESN.quantum_training(U_washout, U_tv, Y_tv, alpha_qc[i])
                    
            Xa_qq       += [Xa_qc]
            Woutt_qq[i]  = Woutt_qc # saving Output matrix as array 
            LHS_qq      += [LHS_qc]
            RHS_qq      += [RHS_qc]
                
alpha_qq = alpha_qc
# Woutt_qq = Woutt_qq

if load_training:
    Woutt_qq = np.reshape(Woutt_qq,[qu_ensemble, QESN.N_units+1,dim]) # If loading previously saved Woutt , need to reshape 4D to 2D

end = timer()

training_time = (end-start)
print(training_time)


if save_training:
    fln      = ('./data/{}/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
    hf       = h5py.File(fln,'w')
    hf.create_dataset('Woutt_qq',data=Woutt_qq)
    hf.close()
# Out:
# Configuration: config4 Emulator: sv_sim Total shots: None Individual Shots: None
# Network 1  out of  1
# Training...
# 2179.0352458395064

# %% [markdown]
# # Predictions

# %%
## MODIFY Post processing functionss
quantum_plots = True
N_test   = dim   #number of intervals in the test set
N_tstart = N_washout          # where the first test interval starts
N_intt   = 10*N_lyap          # length of each test set interval
N_fwd    = 1*N_lyap

len_open = N_washout          # Should be < N_washout because of implementation
len_closed = 10*N_lyap

factor = 100*N_lyap           # statistical predictions

Y_tp      =  []
Yh_tp     =  []
Yh_t_qp   =  []
PH_plot_p  =  []
PH_plot_pq =  []
PH_series  = []
PH_series_q  = []

time_series = np.array([0,1]) # relevant for MFE

for j in range(len(time_series)):
    num_series = time_series[j]
    print('For time series',num_series)

    for i in range(qu_ensemble):
        seed  = i+1
        Win   =  esn.gen_input_matrix(seed)
        W     =  esn.gen_reservoir_matrix(seed)

        if quantum_plots:
            U_wash, Uh_wash , Y_t , Yh_t , PH_plot , Uh_wash_q, Yh_t_q , PH_plot_q = MFE_timeseries_plot(num_series,N_test,N_tstart,N_intt,N_fwd,i,UU,U,U_test,N_washout,N_lyap,ensemble,N_t,minimum,esn,Win,W,QESN,Woutt,Woutt_qq,alpha_qq,plot=True,quantum=True)
            
            Y_tp       +=  [Y_t]
            Yh_tp      +=  [Yh_t]
            Yh_t_qp    +=  [Yh_t_q]
            PH_plot_p  += [PH_plot[i]]
            PH_plot_pq += [PH_plot_q[i]]
            
        else:
            U_wash, Uh_wash , Y_t , Yh_t , PH_plot , Uh_wash_q, Yh_t_q , PH_plot_q = MFE_timeseries_plot(num_series,N_test,N_tstart,N_intt,N_fwd,i,UU,U,U_test,N_washout,N_lyap,ensemble,N_t,minimum,esn,Win,W,QESN,Woutt,Woutt_qq,alpha_qq,plot=True,quantum=False)
            Y_tp      +=  [Y_t]
            Yh_tp     +=  [Yh_t]
            PH_plot_p += [PH_plot[i]]
            
    PH_series   += [PH_plot_p]
    PH_series_q += [PH_plot_pq]
# Out:
# For time series 0
# (320000, 9) (20, 16000, 9) 2000
# Realization    : 1
# Hyperparameters: 0.01 1.0 0.01 [1.e-09]
# Quantum Hyperparameters: 1.0 0.05 1 [1.e-12] Seed: 1
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# PH quantiles [Lyapunov Times]: [0.50204082 0.30204082 0.28571429]
#
# PH quantiles [Lyapunov Times]: [5.48979592 4.69795918 3.68163265]
# For time series 1
# (320000, 9) (20, 16000, 9) 2000
# Realization    : 1
# Hyperparameters: 0.01 1.0 0.01 [1.e-09]
# Quantum Hyperparameters: 1.0 0.05 1 [1.e-12] Seed: 1
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# PH quantiles [Lyapunov Times]: [0.13061224 0.09387755 0.06938776]
#
# PH quantiles [Lyapunov Times]: [1.91836735 0.69795918 0.04081633]
