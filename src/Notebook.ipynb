# %% [markdown]
# # Solving Dynamical Systems using Reservoir Computing

# %%
from QRC.solvers import *
from QRC.systems import *
from QRC.post_process import *
from QRC.crc import *
from QRC.qrc import *
from QRC.validation import *
#numpy
import numpy as np
#plotting libraries
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib as mpl
#scipy libraries
import sklearn
from skopt.space import Real
from skopt.learning import GaussianProcessRegressor as GPR
from skopt.learning.gaussian_process.kernels import Matern, WhiteKernel, Product, ConstantKernel
#time libraries
import h5py
import time
from datetime import date
from timeit import default_timer as timer
today = date.today()

mpl.rc('text', usetex = True)
mpl.rc('font', family = 'serif')
mpl.rcParams['text.usetex']

#TODO
# Add config file so that to run on HPC
# Out:
# True

# %% [markdown]
# # Select Systems and Parameters

# %%
#for Lorenz 63:
if __name__ == "__main__":
    dt = 0.01
    tot_steps = 100000
    upsample = 1
    q0 =  np.array([7.432487609628195, 10.02071718705213, 29.62297428638419])
    #q0 =  np.array([0, 1, 1])
    N_transient = 2000


save_fold = 'VPT_L63'
system = Systems(dt,tot_steps,q0,upsample,N_transient)

dim,N_lyap,N_t = system.set_param_lorenz63() # FOR MFE, N_t should be input so in set_param_MFE -- make it as input
q = system.gen_data_lorenz63()


#for MFE:
# if __name__ == "__main__":
#     dt = 0.25
#     tot_steps = 20000
#     upsample = 1
#     q0   = np.array([1, 0.07066, -0.07066, 0, 0, 0, 0, 0, 0]) 
#     N_t = 2000
#     N_transient = 1000

# save_fold= 'MFE'
# system = Systems(dt,tot_steps,q0,upsample,N_transient)
# sys = 'MFE'
# dim,N_lyap = system.set_param_MFE(N_t) 

# run = False
# save= False
# load = True

# if run:
#     q = system.gen_data_MFE()

# if save:
#     fln = './data/MFE'+'MFE'+'_dt='+str(dt)+'_Nt='+str(N_t)+'_dim='+str(dim)+'_date='+str() # Enter Date
#     hf = h5py.File(fln,'w')
#     hf.create_dataset('q',data=q)
#     hf.close()

# if load:
#     hf      = h5py.File('./data/MFE/'+'MFE'+'_dt='+str(dt)+'_Nt='+str(N_t)+'_dim='+str(dim)+'_date='+str('2023-07-31'))
#     q       = np.array(hf.get('q'))
#     hf.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 15
#      12 system = Systems(dt,tot_steps,q0,upsample,N_transient)
#      14 dim,N_lyap,N_t = system.set_param_lorenz63() # FOR MFE, N_t should be input so in set_param_MFE -- make it as input
# ---> 15 q = system.gen_data_lorenz63()
#      18 #for MFE:
#      19 # if __name__ == "__main__":
#      20 #     dt = 0.25
#    (...)
#      47 #     q       = np.array(hf.get('q'))
#      48 #     hf.close()
#
# File ~/OpenAccess/OptimalTraining_RFQRC/src/QRC/systems.py:117, in Systems.gen_data_lorenz63(self)
#     114 q         = np.zeros((self.N_t,self.tot_steps-self.N_transient,self.dim))
#     116 for i in range(self.N_t):
# --> 117     q[i]       = self.solve_ODE(self.solve_lorenz63)
#     119 return(q)
#
# File ~/OpenAccess/OptimalTraining_RFQRC/src/QRC/solvers.py:57, in Solvers.solve_ODE(self, func)
#      53 def solve_ODE(self,func):
#      55     ''' Compute time series '''
# ---> 57     q   = self.RK4(func)
#      59     return q[self.N_transient+1:]
#
# File ~/OpenAccess/OptimalTraining_RFQRC/src/QRC/solvers.py:34, in Solvers.RK4(self, func)
#      30 k        = np.zeros(self.tot_steps+1)
#      32 for i in 1+np.arange(self.tot_steps):
# ---> 34     k1   = self.dt * func(q[i-1])
#      35     k2   = self.dt * func(q[i-1] + k1/2)
#      36     k3   = self.dt * func(q[i-1] + k2/2)
#
# File ~/OpenAccess/OptimalTraining_RFQRC/src/QRC/systems.py:62, in Systems.solve_lorenz63(self, u)
#      60 x, y, z = u
#      61 #print(self.sigma,self.r,self.b)
# ---> 62 return np.array([(self.sigma)*(y-x), x*(self.r-z)-y, x*y-self.b*z])
#
# KeyboardInterrupt:

# %% [markdown]
# # Pre-process input data

# %%
data_inputs = True
noise       = False # to add noise in flattened time series 
scaling     = True # to scale flattened time series 

if data_inputs:
    N_ts        = 1 # 1 for L63 and L96, 20 for MFE
    N_test_stat = 500 # Time series for testing after N_ts

    N_washout  = 2*N_lyap #10 before for L96 10 D , 2 before for L63 / MFE  
    N_val      = 3*N_lyap # 3 for L63 , # 5 for L96 , 2*N_lyap for MFE
    N_train    = 20*N_lyap #200 before for L96 10D , 20 before for L63 / MFE  
    N_test     = 200*N_lyap
 


# All above in this block are Inputs
q_unscaled = q
UU = q # backup of complete time series
print('Laminarized precentage', np.round(100-((q.shape[0])*100/N_t),2),'(relevant for MFE)')

q = q[:N_ts+N_test_stat,:,:] # trimmed time series

print('Retaining ',N_ts, 'series for training and validation')
print('Additional ',N_test_stat, 'series for testing and statistical predictions')

# Rescaling Input Time Series after flattening it (only retained series)
q0 = q.shape[0] # Total time series, Train+Val+Test
q1 = q.shape[1] # Length of each time series
q_U = q.reshape(q0*q1, dim)

if scaling:
    q = sklearn.preprocessing.minmax_scale(q_U, feature_range=(0, 1), axis=0, copy=True) # rescaling flattened array
    q  = q.reshape(q0,q1,dim) # making 3 dimensional again

# from here q has scaled data
q_tv = q[:N_ts,:,:]  # From q retaining training set (N_ts)
q_test = q[N_ts:N_ts+N_test_stat,:,:]  #From q removing retaining test set(N_test_stat)

# Training, Validation Parameters
UU = q_tv # Training, validation set
N0 = UU.shape[0] # Retained Time series for training
N1 = UU.shape[1] # Length of each time series
print('UU Size =',UU.shape) # 3 dim
U = UU.reshape(N0*N1, dim) # Generating flattened time series for addition of noise and normalization
print('U Size =',U.shape) # 2 dim 

if noise: # adding noise in training set
    target_snr_db=40
    seed=0
    UU = add_noise(U,target_snr_db,seed,dim,N0,N1)

#compute norm
U_data = U[:N_washout+N_train+N_val]
m = U_data.min(axis=0)
M = U_data.max(axis=0)
norm = M-m
u_mean = U_data.mean(axis=0)

# washout
U_washout = UU[:,:N_washout]
# training + validation
U_tv  = UU[:,N_washout:N_washout+N_train+N_val-1]
Y_tv  = UU[:,N_washout+1:N_washout+N_train+N_val]
# Testing
U_test  = UU[:,N_washout+N_train+N_val:N_washout+N_train+N_val+N_test-1]
Y_test  = UU[:,N_washout+N_train+N_val+1:N_washout+N_train+N_val+N_test]

print('N_lyap:', N_lyap)
print('N_train =',int(N_train/N_lyap),'N_lyap',' x ',str(N_ts),'series')
print('N =',int((N_washout+N_val+N_train)/N_lyap),'N_lyap',', Total steps of training=',int(N_washout+N_val+N_train),', Out of = ',N0*N1)
print('The shape of q_tv is '+str(q_tv.shape)+ ' to train on ' +str(N_ts)+  ' time series')
print('The shape of q_test is '+str(q_test.shape)+ ' to test ' +str(N_test_stat)+  ' time series, and for stats predictions (relevant for MFE)')
print('The shape of q is '+str(q.shape)+ ' combining above')
print('The shape of U_test is '+str(U_test.shape)+ ' combining above')
# Out:
# Laminarized precentage 0.0 (relevant for MFE)
# Retaining  1 series for training and validation
# Additional  500 series for testing and statistical predictions
# UU Size = (1, 98000, 3)
# U Size = (98000, 3)
# N_lyap: 111
# N_train = 20 N_lyap  x  1 series
# N = 25 N_lyap , Total steps of training= 2775 , Out of =  98000
# The shape of q_tv is (1, 98000, 3) to train on 1 time series
# The shape of q_test is (0, 98000, 3) to test 500 time series, and for stats predictions (relevant for MFE)
# The shape of q is (1, 98000, 3) combining above
# The shape of U_test is (1, 22199, 3) combining above

# %% [markdown]
# # Visualize input data

# %%
# l1 = 8000
# l2 = 5000
# l3 = 5000

# plot_lorenz63_attractor(U,l1)
# plot_lorenz63_time(U,N_lyap,l2,l3)
# plt.show()

# %% [markdown]
# # Classical Reservoir Initialization

# %%
# Required Input Parameters
bias_in   = np.array([np.mean(np.abs((U_data-u_mean)/norm))]) #input bias (average absolute value of the inputs)
bias_out  = np.array([1.]) #output bias 
N_units   = 1024 #neurons
density = 0.11 # L63
#density = 0.01 # L96
#connectivity = 30

# Predefining Hyperparameter to initiate a class
tikh = np.array([1e-9])  # Tikhonov factor 
sigma_in = 1 # input scaling
rho = 1
epsilon = 1

# Random Weight Matrices Seed
seed = 2

sparseness = 1 - density
connectivity = (1 -  sparseness)*(N_units-1)

# sparseness = 1-((connectivity)/(N_units-1))
# density    = 1-sparseness
print('Density(D) = ',np.round(density,2))
print('Connectivity = ', np.round(connectivity,2))

esn = EchoStateNetwork(tikh,sigma_in,rho,epsilon,bias_in,bias_out,N_units,dim,density)
esn.norm_u = norm
# Out:
# Density(D) =  0.11
# Connectivity =  112.53

# %% [markdown]
# # Validation (hyperparameter tuning)

# %%
n_in        = 10               #Number of Initial random points
n_tot       = 50               #Total number of function evaluations

#range for hyperparameters 
spec_in     = np.log10(0.01)   
spec_end    = np.log10(1.0)   
epsilon_in  = 0.01
epsilon_end = 1
scaling_in  = 0.01
scaling_end = 1
#Number of Networks in the ensemble
ensemble = 5      
    
search_space = [Real(spec_in, spec_end, name='spectral_radius'),
            Real(epsilon_in, epsilon_end, name='epsilon'),
            Real(scaling_in,scaling_end, name = 'input_scaling')]

kernell = ConstantKernel(constant_value=1.0, constant_value_bounds=(1e-1, 3e0)) *\
            Matern(length_scale=[0.2,0.1,0.3], nu=2.5, length_scale_bounds=(5e-2, 1e1)) 


k= 0
# Which validaton strategy (implemented in Val_Functions.ipynb)
val      = RVC_Noise_upt
N_fo     = max(50,2)            # number of validation intervals
N_in     = N_washout                  # timesteps before the first validation interval (can't be 0 due to implementation)
N_fw     = (N_train-N_val)//(N_fo-1) # how many steps forward the validation interval is shifted (in this way they are evenly spaced)

#Quantities to be saved
par      = np.zeros((ensemble, 5))      # GP parameters
x_iters  = np.zeros((ensemble,n_tot,len(search_space))) # coordinates in hp space where f has been evaluated
f_iters  = np.zeros((ensemble,n_tot))   # values of f at those coordinates
minimum  = np.zeros((ensemble, len(search_space)+2))      # minima found per each member of the ensemble

# to store optimal hyperparameters and matrices
tikh_opt = np.zeros(n_tot)
Woutt    = np.zeros(((ensemble, N_units+1,dim)))
Winn     = [] #save as list to keep single elements sparse
Ws       = [] 
biass    = []
rho_ens  = []
epsilon_ens = []
sigma_in_ens = []
Xa_cc        = []
LHS_cc       = []
RHS_cc       = []

# save the final gp reconstruction for each network
gps        = [None]*ensemble

# to print performance of every set of hyperparameters
# print_flag = False

# %%
## TODO fix k, global issues for classical hyperparam opt
run_hyperparam = True
save = True

if run_hyperparam:
    for i in range(ensemble):
        
        print('Realization    :',i+1)
        
        k   = 0
        
        # Win and W generation
        seed= i+1
        rnd = np.random.RandomState(seed)

        Win =  esn.gen_input_matrix(seed)
        W =  esn.gen_reservoir_matrix(seed)
        
        # Bayesian Optimization
        tt       = time.time()
        res      = validate(val,kernell,search_space,n_in,n_tot,esn,tikh,N_fo,N_fw,N_in,N_val,N_washout,U,U_washout,U_tv,Y_tv,Win,W,k,tikh_opt)
        print('Total time for the network:', time.time() - tt)
        
        #Saving Quantities for post_processing
        gps[i]     = res.models[-1]    
        gp         = gps[i]
        x_iters[i] = np.array(res.x_iters)
        f_iters[i] = np.array(res.func_vals)
        minimum[i] = np.append(res.x,[tikh_opt[np.argmin(f_iters[i])],res.fun])
        params     = gp.kernel_.get_params()
        key        = sorted(params)
        par[i]     = np.array([params[key[2]],params[key[5]][0], 1, gp.noise_,params[key[5]][1]])

        esn.rho      = 10**minimum[i,0]
        esn.epsilon  = minimum[i,1]
        esn.sigma_in = minimum[i,2]

        Woutt[i] = esn.train(U_washout, U_tv, Y_tv,Win,W)[1]

        Winn    += [Win] 
        Ws      += [W]   

        #Plotting Optimization Convergence for each network
        print('Best Results: x', 10**minimum[i,0], minimum[i,1],minimum[i,2] ,minimum[i,3],', Min Obj Function =', minimum[i,4])
        print('Hyperparamters:',esn.rho,esn.epsilon,esn.sigma_in)

        plt.rcParams["figure.figsize"] = (15,2)
        
        
        if save:    
            fln = './data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble) 
            hf = h5py.File(fln,'w')
            hf.create_dataset('minimum',data=minimum)
            hf.close()
# Out:
# Realization    : 1
# closed-loop time: 5.155840158462524
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 0.47554079566863
# closed-loop time: 4.966776132583618
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 3.6080264293540925
# closed-loop time: 4.94220232963562
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 0.7690943623649186
# closed-loop time: 4.933175325393677
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 -3.7099094408086275
# closed-loop time: 4.943788290023804
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 3.326463713489376
# closed-loop time: 4.93360710144043
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 -2.85016903156751
# closed-loop time: 4.9426045417785645
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 2.9598614396090066
# closed-loop time: 4.939450740814209
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 1.5493024684546666
# closed-loop time: 4.912622690200806
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 1.3439812932972053
# closed-loop time: 4.866369009017944
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 -1.753427362837828
# closed-loop time: 4.880854606628418
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -8.97209749830884
# /home/oa1422/OpenAccess/env_opt/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# closed-loop time: 4.881705284118652
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -8.97209749830884
# closed-loop time: 4.878555059432983
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 1.0 -3.9211970230911817
# closed-loop time: 4.892300128936768
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6312889622298599 -9.411476482143675
# closed-loop time: 4.872349500656128
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.43 1.0 1e-09 0.01 2.0699247630240762
# closed-loop time: 4.8854570388793945
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.7822096504677738 -9.131901349672532
# closed-loop time: 4.876713752746582
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.28 1.0 1e-09 1.0 -6.644571988170353
# closed-loop time: 4.922628402709961
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8589851920439227 1e-09 0.6408441105097981 -9.402784931346492
# closed-loop time: 4.882594347000122
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9307724899508132 1e-09 0.6482642543460763 -9.31686497328251
# closed-loop time: 4.92786169052124
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7304860464441363 1e-09 1.0 -8.882951488929013
# closed-loop time: 4.9409966468811035
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.01 2.9109894239197285
# closed-loop time: 4.92154335975647
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7518209738360244 1e-09 0.7580625514869702 -9.110644240061117
# closed-loop time: 4.908313512802124
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7589096739452268 1e-09 0.5978548914610535 -9.373523567397696
# closed-loop time: 4.904633283615112
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.5435573487799475 -9.760855494571869
# closed-loop time: 4.907132148742676
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.41 1.0 1e-09 0.5089462380093381 -6.765237265719145
# closed-loop time: 4.907491207122803
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9043482740648092 1e-09 0.5272958688506763 -9.787408227724766
# closed-loop time: 4.935375690460205
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.3932227834940961 -3.273861731772957
# closed-loop time: 4.9208457469940186
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.4890611626023334 -9.535307108128858
# closed-loop time: 4.932162761688232
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8600320607597348 1e-09 0.900513244319092 -9.11482660084134
# closed-loop time: 4.937726020812988
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.01 -1.344533435764329
# closed-loop time: 4.916654348373413
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.37121330260323715 1e-09 1.0 -7.548187693819869
# closed-loop time: 4.9202516078948975
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9297993911760611 1e-09 0.5437638988099641 -9.899737604349982
# closed-loop time: 4.960705041885376
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7752001143200768 1e-09 0.4759252809080097 -9.089028086518402
# closed-loop time: 4.9130775928497314
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.1 1.0 1e-09 0.7877172313464247 -5.556906401980641
# closed-loop time: 4.916031837463379
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.583028557906916 1e-09 0.8766115742983082 -8.572303373224635
# closed-loop time: 4.913393020629883
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.42967052182980253 -1.4639569687324914
# closed-loop time: 4.908238172531128
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.52 1.0 1e-09 0.8122930339199343 -7.299812265524364
# closed-loop time: 4.928281545639038
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 1.0 1e-09 1.0 -5.742848692833552
# closed-loop time: 4.916555881500244
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.31 0.5534448035747748 1e-09 0.9883119952031089 -5.593659739884157
# closed-loop time: 4.9342381954193115
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9136011788988749 1e-09 0.5512080937073423 -9.861784158790586
# closed-loop time: 4.906261920928955
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.95 0.04878950741656102 1e-09 0.9850348166684713 3.232037177846061
# closed-loop time: 4.885238885879517
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5465452289020942 1e-09 1.0 -8.494343492514725
# closed-loop time: 4.878873348236084
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5680114645873011 1e-09 0.5747951535307048 -8.880017521262275
# closed-loop time: 4.895284414291382
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.01 1e-09 0.01 1.1094873656838802
# closed-loop time: 4.903834581375122
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.01 4.405010700073156
# closed-loop time: 4.910049915313721
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.42108354306162765 1e-09 0.01 1.6352400550050412
# closed-loop time: 4.913482189178467
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5792874960324094 1e-09 0.4033526829611838 -7.976885322707009
# closed-loop time: 4.90729284286499
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.43 0.6820316548214128 1e-09 0.5317305319412173 -6.24595682248296
# closed-loop time: 4.921690940856934
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.4542437741991494 1e-09 0.7480797318142433 -8.435657507899395
# closed-loop time: 4.910603284835815
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -1.4894417106190685
# Total time for the network: 295.93023014068604
# Best Results: x 1.0 0.5437638988099641 0.9297993911760611 0.0 , Min Obj Function = -9.899737604349982
# Hyperparamters: 1.0 0.5437638988099641 0.9297993911760611
# Realization    : 2
# closed-loop time: 5.013672590255737
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 0.4901163618272248
# closed-loop time: 4.924489974975586
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 3.464948778974244
# closed-loop time: 4.925856351852417
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 0.6853745167783982
# closed-loop time: 4.915753602981567
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 -3.9831393813198726
# closed-loop time: 4.924487829208374
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 3.231106976071934
# closed-loop time: 4.911168813705444
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 -2.841566320559764
# closed-loop time: 4.915203809738159
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 3.2828828930607905
# closed-loop time: 4.935838937759399
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 1.9094561911202164
# closed-loop time: 4.915569543838501
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 1.8120594068854217
# closed-loop time: 4.92489767074585
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 -1.8392472344428266
# closed-loop time: 4.9027018547058105
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.76 1.0 1e-09 1.0 -7.931863768148644
# closed-loop time: 4.940889835357666
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -9.310480458700805
# closed-loop time: 4.9296276569366455
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.01 2.2859528669205122
# closed-loop time: 4.912644863128662
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.847294485621926 1e-09 1.0 -9.360963778556528
# closed-loop time: 4.905290365219116
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8358890295384063 1e-09 1.0 -9.349120834850996
# closed-loop time: 4.925997734069824
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8790357124059712 1e-09 0.8596341266591571 -8.985328685790606
# closed-loop time: 4.902395009994507
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.873865219959968 1e-09 1.0 -9.34688998093829
# closed-loop time: 4.914920806884766
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.95 0.01 1e-09 0.9802866893910137 3.634148458696517
# closed-loop time: 4.9012696743011475
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.883635656695408 1e-09 1.0 -9.36115732015231
# closed-loop time: 4.919250011444092
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.01 -1.3451809940582373
# closed-loop time: 4.916574001312256
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 1.0 1e-09 1.0 -5.731635197385945
# closed-loop time: 4.892158031463623
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.908955700695479 -9.552049080460668
# closed-loop time: 4.903632879257202
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.7701401824306373 -9.15754226152315
# closed-loop time: 4.926831007003784
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 1.0 -4.057745702813104
# closed-loop time: 4.9101433753967285
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.11 1.0 1e-09 0.6120357026427226 -5.573197312297883
# closed-loop time: 4.888245105743408
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9356501965877724 1e-09 0.8978291079589268 -9.341633136494663
# closed-loop time: 4.92010760307312
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.4172888501532297 -3.880635123743308
# closed-loop time: 4.9318320751190186
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.6631566736691216 -1.47357410842183
# closed-loop time: 4.888591051101685
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6570488356438863 1e-09 1.0 -9.132966094600981
# closed-loop time: 4.9154887199401855
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 1.0 1e-09 0.01 0.5627808415599622
# closed-loop time: 4.915931224822998
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.22 0.7094400223342979 1e-09 1.0 -5.703103522362413
# closed-loop time: 4.904987573623657
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6417034342341147 1e-09 0.861368723914183 -9.14904413864553
# closed-loop time: 4.886027812957764
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.638051714746488 1e-09 0.6395107639302317 -9.376465949367612
# closed-loop time: 4.916758060455322
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6907191049732051 1e-09 0.6964498312228019 -9.218581475850675
# closed-loop time: 4.925999164581299
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5911110333994001 1e-09 0.7031234033805045 -8.701431397398075
# closed-loop time: 4.918957471847534
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7215102869927812 1e-09 0.544127054681417 -9.552408636929059
# closed-loop time: 4.913957357406616
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6855692582046576 1e-09 0.5772220743350366 -9.434574930644755
# closed-loop time: 4.941631317138672
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.5298813811690637 -9.517299763005532
# closed-loop time: 4.89243483543396
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8528570665744261 1e-09 0.5371139789149727 -9.661111235888177
# closed-loop time: 4.868844985961914
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8394384057877977 1e-09 0.4693765543655886 -9.505740769909398
# closed-loop time: 4.893065690994263
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.66 0.8331445902405831 1e-09 0.51403551719079 -8.261823604654607
# closed-loop time: 4.899122476577759
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6068473059715429 -9.776594244890038
# closed-loop time: 4.862962961196899
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6454791798733022 1e-09 0.4379630697707005 -8.812965467053825
# closed-loop time: 4.9172234535217285
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9401089902240546 1e-09 0.6057961288123177 -9.81291805270333
# closed-loop time: 4.889690160751343
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8575787463589082 1e-09 0.6186520983863719 -9.804340032466227
# closed-loop time: 4.838134527206421
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9443055079629454 1e-09 0.6380910064452898 -9.652650458154513
# closed-loop time: 4.847811698913574
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.368314610546811 -9.830974138439782
# closed-loop time: 5.021730422973633
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9012539927957235 1e-09 0.35905068626191966 -9.681326935072075
# closed-loop time: 4.972195386886597
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.58 1.0 1e-09 0.3457486356025502 -8.17266386898056
# closed-loop time: 5.022556781768799
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.39413883799153043 -9.437482690322755
# Total time for the network: 289.4994251728058
# Best Results: x 1.0 0.368314610546811 1.0 0.0 , Min Obj Function = -9.830974138439782
# Hyperparamters: 1.0 0.368314610546811 1.0
# Realization    : 3
# closed-loop time: 4.8194825649261475
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 0.563370240742297
# closed-loop time: 4.802273511886597
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 3.61431754000068
# closed-loop time: 4.858564853668213
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 0.6310968404307044
# closed-loop time: 4.866665840148926
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 -3.70775451780023
# closed-loop time: 4.857663154602051
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 3.2486081509363816
# closed-loop time: 4.856590032577515
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 -2.602779320758229
# closed-loop time: 4.855576276779175
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 2.757590223844103
# closed-loop time: 4.816168546676636
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 1.973552111360997
# closed-loop time: 4.778246641159058
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 1.9227591586964397
# closed-loop time: 4.797528028488159
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 -1.6825473637969568
# closed-loop time: 4.823784112930298
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -8.695251827131113
# /home/oa1422/OpenAccess/env_opt/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# closed-loop time: 4.870816469192505
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -8.695251827131113
# /home/oa1422/OpenAccess/env_opt/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# closed-loop time: 4.856562852859497
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -8.695251827131113
# closed-loop time: 4.808588981628418
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.7732795485696864 -9.195143247785118
# closed-loop time: 4.833584308624268
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.3498236781105136 -9.008205059599154
# closed-loop time: 4.821833848953247
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.5847420170545493 -4.0881879236507395
# closed-loop time: 4.836665868759155
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.7 1.0 1e-09 0.6190962346108074 -8.797453116420499
# closed-loop time: 4.825793266296387
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9220030098466662 1e-09 0.7680310070489179 -9.130215915669998
# closed-loop time: 4.8408989906311035
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.01 1.5151415681035743
# closed-loop time: 5.048835754394531
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.46027175996276354 -9.7041568788473
# closed-loop time: 4.900079011917114
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.869352485114979 1e-09 0.4635947689253137 -9.60501807924874
# closed-loop time: 5.214708089828491
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.16 1.0 1e-09 1.0 -5.751123936951011
# closed-loop time: 4.904428243637085
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9435991723010094 1e-09 0.5129751378654305 -9.488147227710934
# closed-loop time: 5.159438610076904
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.47 1.0 1e-09 0.43269146423862787 -6.478915267159504
# closed-loop time: 4.999105930328369
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6366929613106852 1e-09 1.0 -8.650910568461288
# closed-loop time: 5.2347495555877686
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.51 1.0 1e-09 0.8365323288018375 -7.493096497941663
# closed-loop time: 4.905495643615723
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.01 -1.34715898838983
# closed-loop time: 4.921695947647095
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6552275565791014 -9.692412139274257
# closed-loop time: 4.927273273468018
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9380952327561253 1e-09 0.4307246967578019 -9.42317397052542
# closed-loop time: 4.898361682891846
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.5965415810068968 -9.728746906919618
# closed-loop time: 4.936691761016846
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6039034671433569 -9.738668344774966
# closed-loop time: 5.190994739532471
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7061248122301342 1e-09 0.5417777891998014 -9.014089550459376
# closed-loop time: 4.917473077774048
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9366234913060946 1e-09 0.6237574272063918 -9.732712866515266
# closed-loop time: 4.947726011276245
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6212137548294794 -9.782556843700426
# closed-loop time: 4.882485389709473
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.01 1e-09 1.0 3.3813561451258187
# closed-loop time: 4.908094882965088
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8017020927791184 1e-09 1.0 -8.914696263094164
# closed-loop time: 4.911923170089722
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8315068927541528 1e-09 0.5976400897642897 -9.46937670105562
# closed-loop time: 4.874468803405762
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6832110713606662 1e-09 0.8377923352954296 -8.869568407402488
# closed-loop time: 4.903781414031982
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7328507002918336 1e-09 0.39127343124510305 -8.972444937360976
# closed-loop time: 4.866085529327393
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 1.0 -3.7174161550715037
# closed-loop time: 4.872546672821045
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.34 0.6764171772235046 1e-09 1.0 -6.057764135508956
# closed-loop time: 4.8773486614227295
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6048811475002206 -9.740020591538551
# closed-loop time: 4.858904600143433
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6328716701383792 -9.80804061111234
# closed-loop time: 4.85801887512207
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.4175421964638461 -1.4633114856897556
# closed-loop time: 4.844179630279541
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8327551872546396 1e-09 0.8989966234185045 -9.111364705290832
# closed-loop time: 4.831303119659424
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.26688492246069634 -1.189794273282653
# closed-loop time: 4.842663526535034
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.5763827819587095 -9.755121940709424
# closed-loop time: 4.840980768203735
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6339231415995848 -9.812560600334578
# closed-loop time: 4.8589231967926025
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.08 0.9992674288088678 1e-09 0.7450955835023636 -5.336194785987444
# closed-loop time: 4.863085985183716
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9653962059634641 1e-09 0.6399408733391381 -9.839376470094935
# Total time for the network: 288.21454977989197
# Best Results: x 1.0 0.6399408733391381 0.9653962059634641 0.0 , Min Obj Function = -9.839376470094935
# Hyperparamters: 1.0 0.6399408733391381 0.9653962059634641
# Realization    : 4
# closed-loop time: 4.8857104778289795
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 0.5268225630563105
# closed-loop time: 4.880737543106079
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 3.5790595732954267
# closed-loop time: 4.930653095245361
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 0.8700676809375771
# closed-loop time: 4.913210391998291
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 -3.933690698847085
# closed-loop time: 4.924237966537476
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 3.3051637828268325
# closed-loop time: 4.894347667694092
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 -2.9761441027879023
# closed-loop time: 4.9062745571136475
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 2.787102369809333
# closed-loop time: 4.8793885707855225
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 1.8412194083875137
# closed-loop time: 4.881450891494751
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 2.7882990273097694
# closed-loop time: 4.889979124069214
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 -1.6087910132331322
# closed-loop time: 4.89999532699585
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 1.0 -4.360068486697739
# closed-loop time: 4.910488843917847
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -9.231534441495072
# /home/oa1422/OpenAccess/env_opt/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# closed-loop time: 5.367348670959473
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -9.231534441495072
# closed-loop time: 4.954021692276001
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.1787135308818276 1e-09 0.01 -0.04346881294980523
# closed-loop time: 4.956547498703003
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.01 2.471306329600482
# closed-loop time: 4.925012826919556
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9104113095137328 1e-09 1.0 -9.130666117786832
# closed-loop time: 4.930256605148315
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9951738349232188 1e-09 0.8722490210023582 -9.583076858158798
# closed-loop time: 4.948916912078857
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.39 1.0 1e-09 0.9075160627788563 -7.3821999291574025
# closed-loop time: 4.924875497817993
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.7085172790634983 -9.996894734317879
# closed-loop time: 4.958908557891846
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8749794366799696 1e-09 0.7310816059962663 -9.721143136619826
# closed-loop time: 4.956476449966431
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.5910317330325527 -9.950004244182173
# closed-loop time: 4.967563152313232
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.49 1.0 1e-09 0.6022194063531763 -7.411143708251859
# closed-loop time: 4.9542248249053955
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6483943455005956 -10.008211384060964
# closed-loop time: 4.971757888793945
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9159910107846477 1e-09 0.6089077336908948 -9.863598050154131
# closed-loop time: 4.987313747406006
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.01 -1.3466400786859143
# closed-loop time: 4.986599922180176
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.46153284779824766 -4.072082722541977
# closed-loop time: 5.0077064037323
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.07 1.0 1e-09 1.0 -5.534887779745561
# closed-loop time: 4.966312885284424
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5077808070146649 1e-09 1.0 -8.716607478910644
# closed-loop time: 4.977802515029907
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.47942260126579606 -9.422800287082117
# closed-loop time: 4.985101222991943
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7354629473747738 1e-09 0.5162295172250604 -9.212560184218784
# closed-loop time: 4.992895841598511
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6640671907862665 1e-09 0.8608676589574344 -9.097077935210633
# closed-loop time: 5.029019117355347
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.010000000000000002 1e-09 1.0 3.638010292254572
# closed-loop time: 4.953343629837036
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.673948201073232 1e-09 1.0 -9.126171304271868
# closed-loop time: 4.973032474517822
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7500628369248261 1e-09 0.6473251286479194 -9.562676321282382
# closed-loop time: 4.969072103500366
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.6408875892417938 1e-09 1.0 -5.939398998965015
# closed-loop time: 4.957659959793091
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.5373965799054204 -1.46898173488142
# closed-loop time: 4.947539329528809
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.06 1.0 1e-09 0.4112795879842968 -4.789367107291625
# closed-loop time: 4.950799942016602
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5559916499013207 1e-09 0.6226084284489264 -8.98725353331536
# closed-loop time: 4.962684154510498
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6681903962278793 -9.978628657714898
# closed-loop time: 4.9469873905181885
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -1.4898789811642832
# closed-loop time: 4.93565821647644
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.1 1.0 1e-09 0.7156938283714256 -5.51293008115496
# closed-loop time: 4.946510314941406
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.01 2.84361547027099
# closed-loop time: 4.944122314453125
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.4247767445945083 1e-09 0.23394022973028242 0.164435194524575
# closed-loop time: 4.9492270946502686
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8932223581476768 1e-09 0.5230155181382027 -9.354280735091304
# closed-loop time: 4.979514122009277
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.9630196227816178 1e-09 0.6813678618456559 -9.968113397794763
# closed-loop time: 4.946187973022461
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.4 0.6679766874250628 1e-09 0.5780194646371202 -5.036787801880236
# closed-loop time: 4.958034515380859
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.1 0.01 1e-09 0.01 -0.7988951247037432
# closed-loop time: 4.934177875518799
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.7429310003581634 -9.913723288778074
# closed-loop time: 4.925907850265503
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5159459647224753 1e-09 0.8061609918325057 -9.058403668244308
# closed-loop time: 4.941066265106201
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6498045829420362 -9.995803363621208
# Total time for the network: 289.3814082145691
# Best Results: x 1.0 0.6483943455005956 1.0 0.0 , Min Obj Function = -10.008211384060964
# Hyperparamters: 1.0 0.6483943455005956 1.0
# Realization    : 5
# closed-loop time: 4.954148292541504
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.04 0.4485847982117224 1e-09 0.4996440302380306 0.3726512365927135
# closed-loop time: 4.9553375244140625
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.46 0.03492001113356817 1e-09 0.587488519568359 3.559580787144319
# closed-loop time: 4.963562250137329
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.26 0.27096681756866287 1e-09 0.2729104655043761 0.5472921765322776
# closed-loop time: 4.97191047668457
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.02 0.8184358168684602 1e-09 0.6869802450676219 -3.9719807435351147
# closed-loop time: 4.997436046600342
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.20614059490264064 1e-09 0.8919083653725294 3.362260105724993
# closed-loop time: 4.963537931442261
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7301611585810511 1e-09 0.878838790498356 -2.8637127346952376
# closed-loop time: 4.964554071426392
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.12 0.4195307006742683 1e-09 0.14014357087849771 2.634740752709212
# closed-loop time: 4.966546058654785
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.36 0.19080512193899482 1e-09 0.5880623519971393 1.8791529582479598
# closed-loop time: 4.970304012298584
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.45 0.29074091179674016 1e-09 0.11434781515292308 1.896922441958388
# closed-loop time: 4.949777364730835
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.7678012600330337 1e-09 0.06587974559536994 -1.914434237616416
# closed-loop time: 4.973297834396362
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -8.666765159040263
# /home/oa1422/OpenAccess/env_opt/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# closed-loop time: 4.986546516418457
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -8.666765159040263
# /home/oa1422/OpenAccess/env_opt/lib/python3.10/site-packages/skopt/optimizer/optimizer.py:449: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# closed-loop time: 4.975903272628784
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 1.0 -8.666765159040263
# closed-loop time: 4.969893217086792
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.7729646032031854 -9.678562587145688
# closed-loop time: 4.948214530944824
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.43743285205671745 -10.043690955887174
# closed-loop time: 4.970309019088745
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.5083957251454754 -4.234379845337872
# closed-loop time: 4.951514720916748
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.01 3.0070356072588713
# closed-loop time: 4.982150554656982
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.5599308036805668 -9.315206732548418
# closed-loop time: 4.9658589363098145
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.28 1.0 1e-09 0.8562447377012913 -6.81712556378871
# closed-loop time: 4.956535339355469
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.42 1.0 1e-09 0.4384507822737837 -7.124062612194662
# closed-loop time: 4.964397430419922
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8612045505871819 1e-09 0.43464429079334677 -9.497935863237869
# closed-loop time: 4.946769952774048
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.8652778134840398 -9.31191707134877
# closed-loop time: 4.941866159439087
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.3913516793886957 -9.489165408999076
# closed-loop time: 4.938987731933594
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5704012859658658 1e-09 1.0 -8.239077633094617
# closed-loop time: 4.975312948226929
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7949008835661716 1e-09 0.7983215152694837 -8.988263191897142
# closed-loop time: 4.963384389877319
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.01 -1.3486361871621115
# closed-loop time: 4.960815191268921
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.01 1e-09 1.0 -0.08586666150612551
# closed-loop time: 4.972862482070923
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.4585657995082703 -9.967711564899867
# closed-loop time: 4.949822187423706
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 1.0 1e-09 0.6884988544321452 -9.689747817555299
# closed-loop time: 4.929271697998047
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8038237805565588 1e-09 0.9409243496659848 -9.049167265379442
# closed-loop time: 4.907708168029785
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 1.0 -4.308439084489461
# closed-loop time: 4.927495956420898
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.8404405461461824 1e-09 0.6573863274822765 -9.374366602843274
# closed-loop time: 4.957778453826904
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.35 0.8020712506001779 1e-09 1.0 -6.651095985166481
# closed-loop time: 4.945143461227417
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.47 1.0 1e-09 0.6867288002362864 -7.126261285763948
# closed-loop time: 4.933883905410767
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.2572279124511246 -1.0452489734360337
# closed-loop time: 4.962209939956665
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.32675196748738256 -1.46126502631053
# closed-loop time: 4.947504997253418
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.7531420297486531 1e-09 0.5313781383290078 -9.228723387656544
# closed-loop time: 4.96214747428894
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 1.0 1e-09 0.7654509083686887 -4.323332287779266
# closed-loop time: 4.9664013385772705
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.07 1.0 1e-09 1.0 -5.591209686499797
# closed-loop time: 4.971866846084595
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5502628492207824 1e-09 0.8741137564843862 -8.878598151498739
# closed-loop time: 4.956481695175171
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.6049122617844349 1e-09 0.6889649584005658 -8.905760424723425
# closed-loop time: 4.973477602005005
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.581549084533532 1e-09 0.44786969689689665 -8.426079525180432
# closed-loop time: 4.94924521446228
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 0.6502260561813513 -1.4711868591223394
# closed-loop time: 4.956084251403809
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.01 0.01 1e-09 1.0 -1.4853223462769518
# closed-loop time: 4.976731300354004
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.06 1.0 1e-09 0.5727796717558699 -5.325096610863465
# closed-loop time: 4.952328443527222
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 1.0 0.5651754110553158 1e-09 0.575236585993327 -8.643681316094197
# closed-loop time: 5.009015798568726
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.07 0.9850380533777724 1e-09 0.024664247280135367 -0.7427363087474866
# closed-loop time: 4.9412572383880615
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.05 0.9912380854597482 1e-09 0.7851892670218819 -5.523034903387457
# closed-loop time: 4.953263282775879
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.97 0.013280113112659154 1e-09 0.30753271382894176 1.1368470240131479
# closed-loop time: 4.9515380859375
# 1 : Spectral radius, Input Scaling, Tikhonov, Leak rate, MSE: 0.95 0.3891653149369513 1e-09 0.8006711290284431 -7.41591931360687
# Total time for the network: 289.51937341690063
# Best Results: x 1.0 0.43743285205671745 1.0 0.0 , Min Obj Function = -10.043690955887174
# Hyperparamters: 1.0 0.43743285205671745 1.0

# %% [markdown]
# # Loading Hyperparameters

# %%
# hf       = h5py.File('./data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-noise')
# hf       = h5py.File('./data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-noise'+str(noise))
hf       = h5py.File('./data/VPT_L63/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble))
minimum       = np.array(hf.get('minimum'))
hf.close()

#hf       = h5py.File('./data/MFE/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-noise') # With Noise
# hf       = h5py.File('./data/MFE/minimum='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)) # Without noise
# minimum       = np.array(hf.get('minimum'))
# hf.close()


for i in range(ensemble):
    print('Realization    :',i+1)

    esn.rho      = 10**minimum[i,0]
    esn.epsilon  = minimum[i,1]
    esn.sigma_in = minimum[i,2]
    seed= i+1
    rnd = np.random.RandomState(seed)
    
    
    Win =  esn.gen_input_matrix(seed)
    W =  esn.gen_reservoir_matrix(seed)
    
    Xa, Wout_p, LHS, RHS =  esn.train(U_washout, U_tv, Y_tv,Win,W)
    
    Woutt[i] = Wout_p
    
    Winn    += [Win] 
    Ws      += [W]
    Xa_cc   += [Xa]
    LHS_cc  += [LHS]
    RHS_cc  += [RHS]
# Out:
# Realization    : 1
# Realization    : 2
# Realization    : 3
# Realization    : 4
# Realization    : 5

# %% [markdown]
# # Quantum Reservoir Computing - Initialization

# %%
# Defining Qbit and Cbits
n              = 10 # 9 Qubits and classical
Nres           = 2**n # Total Reservoir Size
qubits         = n

# Required Input Parameters
N_units_q      = Nres #neurons or N_res in paper
bias_in        = np.array([np.mean(np.abs((U_data-u_mean)/norm))])  # Input bias, b_in to break the inherent symmetry of ESN Structure
bias_out       = np.array([1]) #output bias 

# Hyperparameters
tikh_q        = np.array([1e-12])  # Tikhonov Param (Beta),  adds a regularization or weight decay term that penalizes large Wout values 
sigma_in_q    = 1
rho_q         = 1.0 # [Spectral Radius]
epsilon_q     = 0.05 # Leaking Rate

# Ensembles for QRC
qu_ensemble   = 5

# %% [markdown]
# # Training

# %%
Configurations = ['Linear+Full+FullSymmetric','Linear+Linear+Linear','None+Linear+Linear','None+Full+FullSymmetric','None+Products+Linear']
config_list    = ['config1','config2','config3','config4','config5']
qc_type        = config_list[3]
config         = 4 # for initializing class its +1 of the list above

emulator_list  = ['sv_sim','qasm_sim']
emulator       = emulator_list[0]

method_list    = ['sv','shots1k','shots5k','shots10k','shots20k','shots30k','shots40k','shots50k','shots75k','shots100k','shots200k','shots1']
shot_list      = [None,1000,5000,10000,20000,30000,40000,50000,75000,100000,200000,400000,1]

## SHOT INPUT
shot_index     = 0

method = method_list[shot_index]
total_shots  = shot_list[shot_index]


shots = total_shots

snapshots = 1
print('Configuration:',qc_type,'Emulator:',emulator,'Total shots:',total_shots,'Individual Shots:',shots)

# Initialize Class
QESN   = QuantumReservoirNetwork(rho_q,epsilon_q,sigma_in_q,tikh_q,bias_in,bias_out,qubits,N_units_q,dim,config,emulator,shots,snapshots)

# Parameterized or not
QESN.method_qc(parameterized=False)

# Generate parameterized quantum circuit for a given configuration
# QESN.gen_param_quantumcircuit()

quantum_training = True
run_training     = True
save_training    = False
load_training    = False

Xa_qq    = []
Woutt_qq    = np.zeros(((qu_ensemble, QESN.N_units+1,dim)))
LHS_qq   = []
RHS_qq   = []
alpha_qc = []

eps_fix  = 0.05
tikh_q   = np.array([1e-12])
eps_q_list = np.linspace(0.05,0.3,qu_ensemble)
eps_q_list = np.ones(len(eps_q_list))*eps_fix
alpha_range    = 4*np.pi

start = timer()

if quantum_training:
    for i in range(qu_ensemble):
        
        print('Network',i+1,' out of ',qu_ensemble)
        seed           = i
        
        # Quantum Variational Part
        QESN.epsilon_q = eps_q_list[i]

        alpha_q          = QESN.gen_random_unitary(i,alpha_range)
        alpha_qc        += [alpha_q]


        if load_training:
            print('Loading existing Wout matrix')
            #hf       = h5py.File('./data/MFE/Woutt_qq='+str(dt)+'-Nres'+str(N_units_q)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'script')#+'-noise')
            #hf        = h5py.File('./data/MFE/Woutt_qq='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            hf       = h5py.File('./data/VPT_L63/Woutt_qq='+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            #hf      = h5py.File('./data/{}_New/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            #hf      = h5py.File('./data/{}/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
            
            Woutt_qq       = np.array(hf.get('Woutt_qq'))
            hf.close()
        

        if run_training:
            print('Training...')
            Xa_qc, Woutt_qc, LHS_qc, RHS_qc = QESN.quantum_training(U_washout, U_tv, Y_tv, alpha_qc[i])
                    
            Xa_qq       += [Xa_qc]
            Woutt_qq[i]  = Woutt_qc # saving Output matrix as array 
            LHS_qq      += [LHS_qc]
            RHS_qq      += [RHS_qc]
                
alpha_qq = alpha_qc
# Woutt_qq = Woutt_qq

if load_training:
    Woutt_qq = np.reshape(Woutt_qq,[qu_ensemble, QESN.N_units+1,dim]) # If loading previously saved Woutt , need to reshape 4D to 2D

end = timer()

training_time = (end-start)
print(training_time)


if save_training:
    fln      = ('./data/{}/Woutt_qq='.format(save_fold)+str(dt)+'-Nres'+str(N_units)+'-Ensemble'+str(qu_ensemble)+'-dim'+str(dim)+'-epsilon_q'+str(eps_fix)+'-tikh'+str(tikh_q)+'-scaling'+str(scaling)+'-noise'+str(noise)+'-'+str(method)+str(qc_type))
    hf       = h5py.File(fln,'w')
    hf.create_dataset('Woutt_qq',data=Woutt_qq)
    hf.close()
# Out:
# Configuration: config4 Emulator: sv_sim Total shots: None Individual Shots: None
# Network 1  out of  5
# Training...
# Network 2  out of  5
# Training...
# Network 3  out of  5
# Training...
# Network 4  out of  5
# Training...
# Network 5  out of  5
# Training...
# 345.519227206707

# %% [markdown]
# # Predictions

# %%
## MODIFY Post processing functionss
quantum_plots = True
N_test   = dim   #number of intervals in the test set
N_tstart = N_washout          # where the first test interval starts
N_intt   = 10*N_lyap          # length of each test set interval
N_fwd    = 1*N_lyap

len_open = N_washout          # Should be < N_washout because of implementation
len_closed = 10*N_lyap

factor = 100*N_lyap           # statistical predictions

Y_tp      =  []
Yh_tp     =  []
Yh_t_qp   =  []
PH_plot_p  =  []
PH_plot_pq =  []
PH_series  = []
PH_series_q  = []

time_series = np.array([0]) # relevant for MFE

for j in range(len(time_series)):
    num_series = time_series[j]
    print('For time series',num_series)

    for i in range(qu_ensemble):
        seed  = i+1
        Win   =  esn.gen_input_matrix(seed)
        W     =  esn.gen_reservoir_matrix(seed)

        if quantum_plots:
            U_wash, Uh_wash , Y_t , Yh_t , PH_plot , Uh_wash_q, Yh_t_q , PH_plot_q = lorenz63_timeseries_plot(N_test,N_tstart,N_intt,N_fwd,i,UU,U,U_test,N_washout,N_lyap,ensemble,N_t,minimum,esn,Win,W,QESN,Woutt,Woutt_qq,alpha_qq,plot=True,quantum=True)
            
            Y_tp       +=  [Y_t]
            Yh_tp      +=  [Yh_t]
            Yh_t_qp    +=  [Yh_t_q]
            PH_plot_p  += [PH_plot[i]]
            PH_plot_pq += [PH_plot_q[i]]
            
        else:
            U_wash, Uh_wash , Y_t , Yh_t , PH_plot , Uh_wash_q, Yh_t_q , PH_plot_q = lorenz63_timeseries_plot(N_test,N_tstart,N_intt,N_fwd,i,UU,U,U_test,N_washout,N_lyap,ensemble,N_t,minimum,esn,Win,W,QESN,Woutt,Woutt_qq,alpha_qq,plot=True,quantum=False)
            Y_tp      +=  [Y_t]
            Yh_tp     +=  [Yh_t]
            PH_plot_p += [PH_plot[i]]
            
    PH_series   += [PH_plot_p]
    PH_series_q += [PH_plot_pq]
# Out:
# For time series 0
# (98000, 3) (1, 98000, 3) 1
# Realization    : 1
# Hyperparameters: 1.0 0.5437638988099641 0.9297993911760611 [1.e-09]
# Quantum Hyperparameters: 1.0 0.05 1 [1.e-12] Seed: 1
# PH quantiles [Lyapunov Times]: [0.33333333 0.30630631 0.22072072]
#
# PH quantiles [Lyapunov Times]: [7.11261261 4.22522523 3.35135135]
# (98000, 3) (1, 98000, 3) 1
# Realization    : 2
# Hyperparameters: 1.0 0.368314610546811 1.0 [1.e-09]
# Quantum Hyperparameters: 1.0 0.05 1 [1.e-12] Seed: 2
# PH quantiles [Lyapunov Times]: [0.79279279 0.53153153 0.40990991]
#
# PH quantiles [Lyapunov Times]: [3.91891892 3.44144144 2.94594595]
# (98000, 3) (1, 98000, 3) 1
# Realization    : 3
# Hyperparameters: 1.0 0.6399408733391381 0.9653962059634641 [1.e-09]
# Quantum Hyperparameters: 1.0 0.05 1 [1.e-12] Seed: 3
# PH quantiles [Lyapunov Times]: [1.40990991 0.93693694 0.82882883]
#
# PH quantiles [Lyapunov Times]: [9.68468468 9.36936937 5.91441441]
# (98000, 3) (1, 98000, 3) 1
# Realization    : 4
# Hyperparameters: 1.0 0.6483943455005956 1.0 [1.e-09]
# Quantum Hyperparameters: 1.0 0.05 1 [1.e-12] Seed: 4
# PH quantiles [Lyapunov Times]: [10. 10. 10.]
#
# PH quantiles [Lyapunov Times]: [3.8018018  3.28828829 2.86936937]
# (98000, 3) (1, 98000, 3) 1
# Realization    : 5
# Hyperparameters: 1.0 0.43743285205671745 1.0 [1.e-09]
# Quantum Hyperparameters: 1.0 0.05 1 [1.e-12] Seed: 5
# PH quantiles [Lyapunov Times]: [0.71171171 0.43243243 0.30630631]
#
# PH quantiles [Lyapunov Times]: [6.74324324 3.48648649 2.97747748]

# %%
minimum
# Out:
# array([[  0.        ,   0.5437639 ,   0.92979939,   0.        ,
#          -9.8997376 ],
#        [  0.        ,   0.36831461,   1.        ,   0.        ,
#          -9.83097414],
#        [  0.        ,   0.63994087,   0.96539621,   0.        ,
#          -9.83937647],
#        [  0.        ,   0.64839435,   1.        ,   0.        ,
#         -10.00821138],
#        [  0.        ,   0.43743285,   1.        ,   0.        ,
#         -10.04369096]])
